# %%
pwd
# Out:
# '/content'

# %%
cd sample_data
# Out:
# /content/sample_data

# %%
mkdir pre_trained_model

# %%
ls
# Out:
# anscombe.json*                mnist_test.csv         README.md*
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  pre_trained_model/

# %%
cd pre_trained_model
# Out:
# /content/sample_data/pre_trained_model

# %%
ls
# Out:
# download.jpg  photo-1535591273668-578e31182c4f.jpg

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet50 import decode_predictions
import tensorflow.keras

# %%
mymodel = ResNet50()
# Out:
# ...
# 102981632/102967424 [==============================] - 4s 0us/step

# %%
myimage = load_img('photo-1535591273668-578e31182c4f.jpg',target_size = (224,224))

# %%
myimage
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F2609E5F990>

# %%
myimage = img_to_array(myimage)

# %%
myimage = myimage.reshape(1,224,224,3)

# %%
myimage = preprocess_input(myimage)

# %%
result = mymodel.predict(myimage)

# %%
result
# Out:
# array([[3.01888048e-09, 2.52134350e-06, 1.63108265e-08, 1.81944202e-07,
#         1.56841293e-06, 2.51791676e-06, 6.60955607e-07, 2.07218977e-06,
#         3.56649934e-07, 5.84830843e-07, 1.83180703e-07, 3.21046343e-07,
#         1.00472043e-07, 3.20912363e-08, 2.71549139e-09, 2.73207974e-07,
#         1.90480691e-07, 1.60818047e-07, 1.90254653e-07, 1.94376184e-07,
#         2.88088433e-08, 3.62119891e-07, 5.34717799e-07, 2.85872443e-06,
#         2.79911601e-05, 3.11813977e-07, 3.24197060e-08, 1.58367982e-07,
#         3.34842895e-07, 9.48823420e-09, 2.17925180e-08, 2.42329691e-07,
#         1.98246113e-08, 2.33942231e-07, 6.91754281e-08, 2.67747513e-08,
#         5.83845789e-08, 3.87810850e-09, 5.00660860e-07, 5.16197289e-08,
#         1.26165132e-08, 6.55424657e-08, 1.03654800e-08, 9.64576614e-08,
#         3.28394805e-08, 4.29528768e-09, 1.88046450e-08, 2.17023022e-08,
#         1.79434068e-09, 1.59171307e-08, 4.34150360e-09, 4.23919772e-07,
# ...

# %%
mylabel = decode_predictions(result)

# %%
mylabel = mylabel[0][0]

# %%
mylabel
# Out:
# ('n02607072', 'anemone_fish', 0.96381134)
